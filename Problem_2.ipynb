# %%
import pandas
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from keras import regularizers
from keras import optimizers
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %%
dataframe = pandas.read_csv("Image_Segmentation.csv", header=None)
dataset = dataframe.values
X = dataset[1:, :-1].astype(float)
# Normalizing the data
X = preprocessing.normalize(X)
Y = dataset[1:, -1]

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)
Y = np_utils.to_categorical(encoded_Y)

# %%
# split into 2000 for train and 300 for test
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1304, random_state=seed)

# %%
def Model_5 ():
    import keras
    from keras.models import Sequential
    from keras.layers import Dense, Dropout, Activation
    from keras.optimizers import Adam
# split into 2000 for train and 300 for test
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1304, random_state=seed)
# create model
    model = Sequential()
    model.add(Dense(5, input_dim=19, activation='relu',kernel_regularizer=regularizers.l2(0.1), kernel_initializer='VarianceScaling',
                bias_initializer='Ones'))

    model.add(Dense(7, activation='sigmoid'))
    adam = Adam(learning_rate=0.1, beta_1=0.9, beta_2=1, amsgrad=False)

# Compile model
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
# Fit the model
    model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=50, batch_size=100)
    score = model.evaluate(X_test, y_test, batch_size=123)
    model.metrics_names
    return score[1]*100

def Model_5_5 ():
    import keras
    from keras.models import Sequential
    from keras.layers import Dense, Dropout, Activation
    from keras.optimizers import Adam
# split into 2000 for train and 300 for test
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1304, random_state=seed)
# create model
    model = Sequential()
    model.add(Dense(5, input_dim=19, activation='relu',kernel_regularizer=regularizers.l2(0.1), kernel_initializer='VarianceScaling',
                bias_initializer='Ones'))
    model.add(Dense(5, activation='relu',kernel_regularizer=regularizers.l2(0.1), kernel_initializer='VarianceScaling',
                bias_initializer='Ones'))

    model.add(Dense(7, activation='sigmoid'))
    adam = Adam(learning_rate=0.1, beta_1=0.9, beta_2=0.95, amsgrad=False)

# Compile model
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
# Fit the model
    model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=50, batch_size=100)
    score = model.evaluate(X_test, y_test, batch_size=123)
    model.metrics_names
    return score[1]*100

def Model_25 ():
    import keras
    from keras.models import Sequential
    from keras.layers import Dense, Dropout, Activation
    from keras.optimizers import Adam
# split into 2000 for train and 300 for test
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1304, random_state=seed)
# create model
    model = Sequential()
    model.add(Dense(25, input_dim=19, activation='relu',kernel_regularizer=regularizers.l2(0.1), kernel_initializer='VarianceScaling',
                bias_initializer='Ones'))
#model.add(Dense(8, activation='relu'))
    model.add(Dense(7, activation='sigmoid'))
    adam = Adam(learning_rate=0.1, beta_1=0.9, beta_2=0.90, amsgrad=False)

# Compile model
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
# Fit the model
    model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=50, batch_size=100)
    score = model.evaluate(X_test, y_test, batch_size=123)
    model.metrics_names
    return score[1]*100

def Model_25_25 ():
    import keras
    from keras.models import Sequential
    from keras.layers import Dense, Dropout, Activation
    from keras.optimizers import Adam
# split into 2000 for train and 300 for test
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1304, random_state=seed)
# create model
    model = Sequential()
    model.add(Dense(25, input_dim=19, activation='relu',kernel_regularizer=regularizers.l2(0.1), kernel_initializer='VarianceScaling',
                bias_initializer='Ones'))
    model.add(Dense(25, activation='relu',kernel_regularizer=regularizers.l2(0.1), kernel_initializer='VarianceScaling',
                bias_initializer='Ones'))

    model.add(Dense(7, activation='sigmoid'))
    adam = Adam(learning_rate=0.1, beta_1=0.9, beta_2=0.99, amsgrad=False)

# Compile model
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
# Fit the model
    model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=50, batch_size=100)
    score = model.evaluate(X_test, y_test, batch_size=123)
    model.metrics_names
    return score[1]*100

# %%
# 4 experimental with 10 repeatation 
Avg_acc=0
Avg_acc_1=0
Avg_acc_2=0
Avg_acc_3=0
for i in range (10):
    mean_5 =Model_5 ()
    mean_5_5 =Model_5_5 ()
    mean_25 =Model_25 ()
    mean_25_25 =Model_25_25 ()
    print("Repeatation %i: %.2f%%" % (i,mean_5))
    print("Repeatation %i: %.2f%%" % (i,mean_5_5))
    print("Repeatation %i: %.2f%%" % (i,mean_25))
    print("Repeatation %i: %.2f%%" % (i,mean_25_25))
    
    Avg_acc += mean_5
    Avg_acc_1 += mean_5_5
    Avg_acc_2 += mean_25
    Avg_acc_3 += mean_25_25
    
    Avg_accurancy_model_5=Avg_acc/10
    Avg_accurancy_model_5_5=Avg_acc_1/10
    Avg_accurancy_model_25=Avg_acc_2/10
    Avg_accurancy_model_25_25=Avg_acc_3/10
    
print("Model_5 final accurancy",Avg_accurancy_model_5)
print("Model_5_5 final accurancy",Avg_accurancy_model_5_5)
print("Model_25 final accurancy",Avg_accurancy_model_25)
print("Model_25_25 final accurancy",Avg_accurancy_model_25_25)
# Out:
# Train on 2000 samples, validate on 300 samples
# Epoch 1/50
# 2000/2000 [==============================] - 0s 165us/step - loss: 1.3886 - accuracy: 0.5489 - val_loss: 1.3846 - val_accuracy: 0.5486
# Epoch 2/50
# 2000/2000 [==============================] - 0s 22us/step - loss: 1.3886 - accuracy: 0.5489 - val_loss: 1.3846 - val_accuracy: 0.5486
# Epoch 3/50
# 2000/2000 [==============================] - 0s 22us/step - loss: 1.3886 - accuracy: 0.5489 - val_loss: 1.3846 - val_accuracy: 0.5486
# Epoch 4/50
# 2000/2000 [==============================] - 0s 21us/step - loss: 1.3886 - accuracy: 0.5489 - val_loss: 1.3846 - val_accuracy: 0.5486
# Epoch 5/50
# 2000/2000 [==============================] - 0s 21us/step - loss: 1.3886 - accuracy: 0.5489 - val_loss: 1.3846 - val_accuracy: 0.5486
# Epoch 6/50
# 2000/2000 [==============================] - 0s 23us/step - loss: 1.3886 - accuracy: 0.5489 - val_loss: 1.3846 - val_accuracy: 0.5486
# Epoch 7/50
# ...

# %%
# Creating single figure that shows average classification accuracies
Acc = [Avg_accurancy_model_5/100,Avg_accurancy_model_5_5/100,Avg_accurancy_model_25/100,Avg_accurancy_model_25_25/100]
X_axis = ('[5]','[5 5]', '[25]','[25 25]')
Y_axis = np.arange(len(X_axis))
plt.bar(Y_axis,Acc,align='center')
plt.xticks(Y_axis,X_axis)
plt.ylabel('Accuracy')
plt.title('Average classification Accurancy Vs.Model')
plt.show()
